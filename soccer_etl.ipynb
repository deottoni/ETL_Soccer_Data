# %% [markdown]
# # Extracting
# We've extracted two datasets from kaggle, one containing 2018 FIFA world cup data on the national squads, and another with data on soccer players from major leagues in the world.

# %%
# import dependencies
import pandas as pd
from sqlalchemy import create_engine
import sqlalchemy
import pymysql
pymysql.install_as_MySQLdb()

# %% [markdown]
# # Transform
#
# We've used pandas to get input csv files, create dataframes, and clean the data.

# %%
# wc csv file path
csv_wc = "data/2018FIFAWC.csv"

# create wc squads df 
wc_df = pd.read_csv(csv_wc)

# clean dataframe
wc_df["Player"] = wc_df["Player"].map(lambda x: x.strip('(captain)'))
wc_df = wc_df.drop(columns=["Player Count","Date Of Birth"])
wc_df = wc_df.rename(columns={"Player":"name_","Group":"group_","Squad Number":"squad_number","Position":"position_"})
wc_df.head()
# Out:
#     Team group_  squad_number position_             name_  Age  Caps  Goals  \
# 0  Egypt      A             1        GK  Essam El-Hadary    45   157      0
# 1  Egypt      A             2        DF          Ali Gabr   29    20      1
# 2  Egypt      A             3        DF  Ahmed Elmohamady   30    77      2
# 3  Egypt      A             4        MF        Omar Gaber   26    23      0
# 4  Egypt      A             5        MF         Sam Morsy   26     4      0
#
#                    Club
# 0            Al-Taawoun
# 1  West Bromwich Albion
# 2           Aston Villa
# 3        Los Angeles FC
# 4        Wigan Athletic

# %%
# players csv file path
csv_players = "data/players.csv"

# create players df
players_df = pd.read_csv(csv_players)

# clean dataframe
players_df = players_df.dropna()
players_df[["National_Kit","Club_Kit","Contract_Expiry"]] = players_df[["National_Kit","Club_Kit","Contract_Expiry"]].astype(int)
players_df["Height"] = players_df["Height"].map(lambda x: x.rstrip(' cm'))
players_df["Weight"] = players_df["Weight"].map(lambda x: x.rstrip(' kg'))
players_df = players_df.rename(columns={"Name":"name_"})
players_df.head()
# Out:
#                name_ Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS             7
# 1       Lionel Messi   Argentina                RW            10
# 2             Neymar      Brazil                LW            10
# 3        Luis Suárez     Uruguay                LS             9
# 4       Manuel Neuer     Germany                GK             1
#
#            Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  \
# 0   Real Madrid            LW         7   07/01/2009             2021      94
# 1  FC Barcelona            RW        10   07/01/2004             2018      93
# 2  FC Barcelona            LW        11   07/01/2013             2021      92
# 3  FC Barcelona            ST         9   07/11/2014             2021      92
# 4     FC Bayern            GK         1   07/01/2011             2021      92
#
#    ... Long_Shots Curve Freekick_Accuracy Penalties  Volleys GK_Positioning  \
# 0  ...         90    81                76        85       88             14
# 1  ...         88    89                90        74       85             14
# 2  ...         77    79                84        81       83             15
# 3  ...         86    86                84        85       88             33
# 4  ...         16    14                11        47       11             91
#
#   GK_Diving  GK_Kicking  GK_Handling  GK_Reflexes
# 0         7          15           11           11
# 1         6          15           11            8
# 2         9          15            9           11
# 3        27          31           25           37
# 4        89          95           90           89
#
# [5 rows x 53 columns]

# %%
columns_to_drop = [
    'Work_Rate', 'Weak_foot', 'Skill_Moves',
    'Ball_Control', 'Dribbling', 'Marking', 'Sliding_Tackle',
    'Standing_Tackle', 'Aggression', 'Reactions', 'Attacking_Position',
    'Interceptions', 'Vision', 'Composure', 'Crossing', 'Short_Pass',
    'Long_Pass', 'Acceleration', 'Speed', 'Stamina', 'Strength', 'Balance',
    'Agility', 'Jumping', 'Heading', 'Shot_Power', 'Finishing',
    'Long_Shots', 'Curve', 'Freekick_Accuracy', 'Penalties', 'Volleys',
    'GK_Positioning', 'GK_Diving', 'GK_Kicking', 'GK_Handling',
    'GK_Reflexes','Club_Joining','Birth_Date','Preffered_Position'
]

players_df_clean = players_df.drop(columns=columns_to_drop)
players_df_clean.head()
# Out:
#                name_ Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS             7
# 1       Lionel Messi   Argentina                RW            10
# 2             Neymar      Brazil                LW            10
# 3        Luis Suárez     Uruguay                LS             9
# 4       Manuel Neuer     Germany                GK             1
#
#            Club Club_Position  Club_Kit  Contract_Expiry  Rating Height  \
# 0   Real Madrid            LW         7             2021      94    185
# 1  FC Barcelona            RW        10             2018      93    170
# 2  FC Barcelona            LW        11             2021      92    174
# 3  FC Barcelona            ST         9             2021      92    182
# 4     FC Bayern            GK         1             2021      92    193
#
#   Weight Preffered_Foot  Age
# 0     80          Right   32
# 1     72           Left   29
# 2     68          Right   25
# 3     85          Right   30
# 4     92          Right   31

# %%
players_df_clean["Height"].min()
# Out:
# '160'

# %% [markdown]
# # Load
# We've used sqlalchemy and pymysql to load our cleaned dataframes to our production database.

# %%
# create connection to db
connection_string = "root:root@127.0.0.1/soccer_data"
engine = create_engine("mysql://{}".format(connection_string))

# %%
# create table for wc data
wc_df.to_sql(name='world_cup_squads', con=engine, if_exists='append', index=False)

# %%
# create table for players data
players_df_clean.to_sql(name='players', con=engine, if_exists='append', index=False)

# %%
# confirm wc table has been added
pd.read_sql_query('select * from world_cup_squads', con=engine).head()
# Out:
#    id   team group_  squad_number position_             name_  age  caps  \
# 0   1  Egypt      A             1        GK  Essam El-Hadary    45   157
# 1   2  Egypt      A             2        DF          Ali Gabr   29    20
# 2   3  Egypt      A             3        DF  Ahmed Elmohamady   30    77
# 3   4  Egypt      A             4        MF        Omar Gaber   26    23
# 4   5  Egypt      A             5        MF         Sam Morsy   26     4
#
#    goals                  club
# 0      0            Al-Taawoun
# 1      1  West Bromwich Albion
# 2      2           Aston Villa
# 3      0        Los Angeles FC
# 4      0        Wigan Athletic

# %%
# confirm players table has been added
pd.read_sql_query('select * from players', con=engine).head()
# Out:
#    id              name_ nationality national_Position  national_Kit  \
# 0   1  Cristiano Ronaldo    Portugal                LS             7
# 1   2       Lionel Messi   Argentina                RW            10
# 2   3             Neymar      Brazil                LW            10
# 3   4        Luis Suárez     Uruguay                LS             9
# 4   5       Manuel Neuer     Germany                GK             1
#
#            club club_position  club_kit  contract_expiry  rating  height  \
# 0   Real Madrid            LW         7             2021      94     185
# 1  FC Barcelona            RW        10             2018      93     170
# 2  FC Barcelona            LW        11             2021      92     174
# 3  FC Barcelona            ST         9             2021      92     182
# 4     FC Bayern            GK         1             2021      92     193
#
#    weight preffered_foot  age
# 0      80          Right   32
# 1      72           Left   29
# 2      68          Right   25
# 3      85          Right   30
# 4      92          Right   31

# %%
# query average age for each national team in the 2018 FIFA WC
avg_age = '''
    SELECT team,AVG(age) 
    FROM world_cup_squads 
    GROUP BY team
'''
pd.read_sql_query(avg_age, con=engine).sort_values(by="AVG(age)",ascending=False)
# Out:
#             team  AVG(age)
# 5     Costa Rica   29.0870
# 15        Mexico   28.8696
# 18        Panama   28.8261
# 0      Argentina   28.6957
# 8          Egypt   28.4348
# 22        Russia   28.2609
# 14         Japan   28.2174
# 23  Saudi Arabia   28.1304
# 12       Iceland   28.1304
# 3         Brazil   28.0000
# 27         Spain   28.0000
# 21      Portugal   27.9130
# 20        Poland   27.8696
# 28        Sweden   27.6957
# 31       Uruguay   27.6522
# 1      Australia   27.6087
# 4       Colombia   27.5652
# 6        Croatia   27.4348
# 26   South Korea   27.2609
# 2        Belgium   27.1304
# 19          Peru   26.9130
# 16       Morocco   26.7826
# 24       Senegal   26.6957
# 11       Germany   26.6957
# 13          Iran   26.6522
# 7        Denmark   26.6087
# 29   Switzerland   26.6087
# 25        Serbia   26.2609
# 30       Tunisia   26.0000
# 9        England   25.5652
# 10        France   25.5652
# 17       Nigeria   25.5217

# %%
# query average age for each national team in the 2018 FIFA WC
avg_rating = '''
    SELECT club,AVG(rating) 
    FROM players 
    GROUP BY club
'''
pd.read_sql_query(avg_rating, con=engine).sort_values(by="AVG(rating)",ascending=False).head(10)
# Out:
#                  club  AVG(rating)
# 210       Real Madrid      86.8182
# 85       FC Barcelona      86.2308
# 87          FC Bayern      85.9231
# 133          Juventus      85.0000
# 62            Chelsea      84.5556
# 30    Atlético Madrid      84.5556
# 158   Manchester City      83.5455
# 197               PSG      83.2308
# 21            Arsenal      82.6364
# 230  Shakhtar Donetsk      82.0000
